# %% [markdown]
# # ECSE 415 Final Project
# # 2 Classification

# %%
# Import necessary packages
import cv2
import numpy as np
import math
import matplotlib.pyplot as plt
import os
import sys
import itertools
from os import listdir
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.svm import LinearSVC
import time
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

# %% [markdown]
# ## Import the dataset

# %%
# Function to load the images given the folder name
def load_folder(folder, num_samples):
    imgs = []
    files = listdir('./MIO-TCD-Classification/train/{}/'.format(folder))
    img_counter = 0
    for img in files:
        # Read the images in grayscale
        img = cv2.cvtColor(cv2.imread('./MIO-TCD-Classification/train/{}/{}'.format(folder,img)), cv2.COLOR_BGR2GRAY)
        # Perform a box blur on the images
        kernel = np.array([[1/9,1/9,1/9], [1/9,1/9,1/9], [1/9,1/9,1/9]])
        img = cv2.filter2D(img, -1, kernel)
        # Resize to reduce computation time
        img = cv2.resize(img, (64,64))
        imgs.append(img)
        img_counter += 1
        if(img_counter==num_samples): break
    return imgs

# %% [markdown]
# Note:
# num_samples = 1500: SVC=63%, LR=63%, KNN=74%
# num_samples = 5000: SVC=65%, LR=64%, KNN=78%
# num_samples = 10000: SVC=68%, LR=68%, KNN=83'

# %%
# The number of images from each class to import
num_samples = 10000
background_samples = 25000
# Import images from each folder
articulated_truck = load_folder('articulated_truck', num_samples)
background = load_folder('background', background_samples)
bicycle = load_folder('bicycle', num_samples)
bus = load_folder('bus', num_samples)
car = load_folder('car', num_samples)
motorcycle = load_folder('motorcycle', num_samples)
non_motorized_vehicle = load_folder('non-motorized_vehicle', num_samples)
pedestrian = load_folder('pedestrian', num_samples)
pickup_truck = load_folder('pickup_truck', num_samples)
single_unit_truck = load_folder('single_unit_truck', num_samples)
work_van = load_folder('work_van', num_samples)

# %% [markdown]
# ## Compute HoG Features

# %%
# Function to compute HoG features of a list of images
def compute_HoG(imgs, cell_size, block_size, nbins, h, w):
    img_features = []
    hog = cv2.HOGDescriptor(_winSize=((w // cell_size[1]) * cell_size[1],
                                  (h // cell_size[0]) * cell_size[0]),
                        _blockSize=(block_size[1] * cell_size[1],
                                    block_size[0] * cell_size[0]),
                        _blockStride=(cell_size[1], cell_size[0]),
                        _cellSize=(cell_size[1], cell_size[0]),
                        _nbins=nbins)
    n_cells = (h // cell_size[0], w // cell_size[1])
    
    for img in imgs:

        hog_feats = hog.compute(img)\
                .reshape(n_cells[1] - block_size[1] + 1,
                        n_cells[0] - block_size[0] + 1,
                        block_size[0], block_size[1], nbins) \
               .transpose((1, 0, 2, 3, 4))  # index blocks by rows first
                
        # computation for BlockNorm

        gradients = np.full((n_cells[0], n_cells[1], nbins), 0, dtype=float)
        cell_count = np.full((n_cells[0], n_cells[1], 1), 0, dtype=int)

        for off_y in range(block_size[0]):
            for off_x in range(block_size[1]):
                gradients[off_y:n_cells[0] - block_size[0] + off_y + 1,
                          off_x:n_cells[1] - block_size[1] + off_x + 1] += \
                    hog_feats[:, :, off_y, off_x, :]
                cell_count[off_y:n_cells[0] - block_size[0] + off_y + 1,
                           off_x:n_cells[1] - block_size[1] + off_x + 1] += 1

        # Average gradients
        gradients /= cell_count
        
        img_features.append(gradients)
        
    return img_features

# %%
# Create the data and labels variables
X = articulated_truck + background + bicycle + bus + car + motorcycle + non_motorized_vehicle + pedestrian + pickup_truck + single_unit_truck + work_van
y = ['articulated_truck']*len(articulated_truck) + ['background']*len(background) + ['bicycle']*len(bicycle) + \
    ['bus']*len(bus) + ['car']*len(car) + ['motorcycle']*len(motorcycle) + ['non_motorized_vehicle']*len(non_motorized_vehicle)\
    + ['pedestrian']*len(pedestrian) + ['pickup_truck']*len(pickup_truck) + ['single_unit_truck']*len(single_unit_truck) + \
    ['work_van']*len(work_van)

# Split the data into a training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=69)

# Define parameters for computing the HoG features
c_size = (4,4)
b_size = (4,4)
bins = 8
height = 64
width = 64

# Compute the HoG Features
HoG_feat = compute_HoG(X_train, c_size, b_size, bins, height, width)
HoG_feat = np.array(HoG_feat)

# %% [markdown]
# ## Reduce dimensionality with PCA

# %%
# Compute PCA for a large number of components
pca = PCA(n_components = 2048)
x_train_PCA = pca.fit_transform(HoG_feat.reshape(HoG_feat.shape[0],-1))
# Find the variances explained
marginal_variances = pca.explained_variance_ratio_

# Plot the total variance explained at for n components
total_variances = [sum(marginal_variances[:i]) for i in range(1,len(marginal_variances)+1)]
plt.title("Total Variance Explained vs. Number of Principal Components")
plt.xlabel("Number of Components"), plt.ylabel("Total Variance Explained")
plt.bar(range(1, len(total_variances) + 1), total_variances)
plt.ylim(ymin=0), plt.xlim(xmin=0, xmax=2048)
plt.grid(True)
plt.show()

# Plot the varaince explained by each component
plt.title("Variance Explained by each Principal Component")
plt.xlabel("Number of Components"), plt.ylabel("Variance Explained")
plt.bar(range(1, len(marginal_variances) + 1), marginal_variances)
plt.ylim(ymin=0), plt.xlim(xmin=0, xmax=2048)
plt.grid(True)
plt.show()

# %%
print(next(x[0] for x in enumerate(total_variances) if x[1] > 0.98))

# Use the number of components representing 99.9% of the data
nb_components = next(x[0] for x in enumerate(total_variances) if x[1] > 0.98)
pca = PCA(n_components = nb_components)
# Prepare training data
X_train_PCA = pca.fit_transform(HoG_feat.reshape(HoG_feat.shape[0],-1))
# Prepare test data
HoG_feat_test = compute_HoG(X_test, c_size, b_size, bins, height, width)
HoG_feat_test = np.array(HoG_feat_test)
X_test_PCA = pca.transform(HoG_feat_test.reshape(HoG_feat_test.shape[0],-1))
# Out:
# 526

# %% [markdown]
# ## Fit SVM and Predict

# %%
# We have chosen the LinearSVC() model from sklearn as our SVM
# Fit the model
then = time.clock()
svc_clf = LinearSVC()
svc_clf.fit(X_train_PCA,y_train)
now = time.clock()
print(now - then)
# Out:
# 146.82689366731756

# %%
# Predict the classes
then = time.clock()
svc_pred = svc_clf.predict(X_test_PCA)
now = time.clock()
print(now - then)
print(classification_report(y_test,svc_pred))
# Out:
# 0.04658985965397733
#                        precision    recall  f1-score   support
#
#     articulated_truck       0.61      0.65      0.63      1497
#            background       0.80      0.93      0.86      3707
#               bicycle       0.71      0.53      0.61       351
#                   bus       0.68      0.75      0.71      1487
#                   car       0.68      0.76      0.72      1499
#            motorcycle       0.58      0.42      0.49       274
# non_motorized_vehicle       0.69      0.13      0.22       274
#            pedestrian       0.67      0.59      0.63       955
#          pickup_truck       0.64      0.70      0.67      1489
#     single_unit_truck       0.57      0.23      0.33       826
#              work_van       0.61      0.52      0.56      1453
#
#           avg / total       0.68      0.69      0.68     13812

# %% [markdown]
# ## Fit Logistic Regression model and predict

# %%
then = time.clock()
lr_clf = LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial')
lr_clf.fit(X_train_PCA,y_train)
now = time.clock()
print(now - then)
# Out:
# 33.26597222295641

# %%
then = time.clock()
lr_pred = lr_clf.predict(X_test_PCA)
now = time.clock()
print(now - then)
print(classification_report(y_test,lr_pred))
# Out:
# 0.04149630862957565
#                        precision    recall  f1-score   support
#
#     articulated_truck       0.62      0.67      0.64      1497
#            background       0.83      0.91      0.87      3707
#               bicycle       0.76      0.56      0.65       351
#                   bus       0.69      0.74      0.71      1487
#                   car       0.70      0.75      0.72      1499
#            motorcycle       0.58      0.49      0.53       274
# non_motorized_vehicle       0.58      0.18      0.27       274
#            pedestrian       0.70      0.63      0.66       955
#          pickup_truck       0.65      0.69      0.67      1489
#     single_unit_truck       0.51      0.32      0.39       826
#              work_van       0.60      0.57      0.58      1453
#
#           avg / total       0.69      0.70      0.69     13812

# %% [markdown]
# ## Fit KNN and predict

# %%
then = time.clock()
knn_clf = KNeighborsClassifier(n_jobs=-1)
knn_clf.fit(X_train_PCA,y_train)
now = time.clock()
print(now - then)
# Out:
# 7.228854710908763

# %%
then = time.clock()
knn_pred = knn_clf.predict(X_test_PCA)
now = time.clock()
print(now - then)
print(classification_report(y_test,knn_pred))
# Out:
# 607.5299239511146
#                        precision    recall  f1-score   support
#
#     articulated_truck       0.77      0.87      0.82      1466
#            background       0.90      0.96      0.93      7663
#               bicycle       0.90      0.63      0.74       341
#                   bus       0.81      0.95      0.87      1488
#                   car       0.87      0.94      0.90      1470
#            motorcycle       0.94      0.69      0.79       299
# non_motorized_vehicle       0.87      0.40      0.55       248
#            pedestrian       0.95      0.44      0.61       896
#          pickup_truck       0.86      0.89      0.87      1465
#     single_unit_truck       0.79      0.56      0.66       769
#              work_van       0.89      0.82      0.85      1457
#
#           avg / total       0.87      0.87      0.86     17562

# %% [markdown]
# # 2.1 Classifier Evaluation

# %%
# Adapted from sklearn Confusion Matrix tutorial
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html#sphx-glr-auto-examples-model-selection-plot-confusion-matrix-py

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize = (12,12))
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %% [markdown]
# ## LinearSVC

# %%
# Perform k-fold cross validation
scoring = {'accuracy' : make_scorer(accuracy_score), 
           'precision' : make_scorer(precision_score, average='macro'),
           'recall' : make_scorer(recall_score, average='macro')}
svc_results = cross_validate(svc_clf, X_train_PCA, y_train, cv=10, verbose=100, scoring = scoring)
print(svc_results)
# Out:
# [CV]  ................................................................
# [CV]  , accuracy=0.6970509383378016, precision=0.6568898827817663, recall=0.5660179551555138, total= 2.3min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.3min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.6948027071893755, precision=0.6428209824959548, recall=0.5606880192535383, total= 2.5min
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  4.9min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.6928872430085558, precision=0.6555251609773123, recall=0.5634392821570707, total= 2.3min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  7.2min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.6929858183211959, precision=0.6481878915646379, recall=0.5613009949006625, total= 2.5min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  9.7min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.6958855098389982, precision=0.6668185877188608, recall=0.5682322820475159, total= 2.3min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 12.1min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.6985688729874776, precision=0.6626136995332158, recall=0.5727164024563922, total= 2.2min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 14.3min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.6862619808306709, precision=0.6559238423833696, recall=0.5556535531183644, total= 2.3min
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 16.7min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.6860539434999361, precision=0.6508186414379918, recall=0.5544707790890926, total= 2.4min
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 19.0min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.692406034262337, precision=0.6388594671261563, recall=0.5578874963121656, total= 2.4min
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 21.5min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.697647660444899, precision=0.6575841210437878, recall=0.5653493745503669, total= 2.3min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 23.8min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 23.8min finished
# {'fit_time': array([136.57, 150.81, 140.48, 149.77, 137.72, 134.19, 137.22, 142.06,
#        143.76, 137.69]), 'score_time': array([0.14, 0.14, 0.14, 0.13, 0.14, 0.14, 0.13, 0.13, 0.13, 0.15]), 'test_accuracy': array([0.7 , 0.69, 0.69, 0.69, 0.7 , 0.7 , 0.69, 0.69, 0.69, 0.7 ]), 'train_accuracy': array([0.71, 0.71, 0.71, 0.71, 0.71, 0.71, 0.71, 0.71, 0.71, 0.71]), 'test_precision': array([0.66, 0.64, 0.66, 0.65, 0.67, 0.66, 0.66, 0.65, 0.64, 0.66]), 'train_precision': array([0.68, 0.68, 0.68, 0.68, 0.68, 0.68, 0.68, 0.68, 0.68, 0.68]), 'test_recall': array([0.57, 0.56, 0.56, 0.56, 0.57, 0.57, 0.56, 0.55, 0.56, 0.57]), 'train_recall': array([0.58, 0.58, 0.58, 0.58, 0.58, 0.58, 0.58, 0.58, 0.58, 0.58])}

# %%
# print(svc_results['test_accuracy'])
print('Test Accuracy:')
print(np.mean(svc_results['test_accuracy']))
print(np.std(svc_results['test_accuracy']))

print('Test Precision:')
print(np.mean(svc_results['test_precision']))
print(np.std(svc_results['test_precision']))

print('Test Recall:')
print(np.mean(svc_results['test_recall']))
print(np.std(svc_results['test_recall']))
# Out:
# Test Accuracy:
# 0.6934550708721248
# 0.004153823954122304
# Test Precision:
# 0.6536042277063053
# 0.008138047064043615
# Test Recall:
# 0.5625756139040683
# 0.005439597943200609

# %%
lr_results = cross_validate(lr_clf, X_train_PCA, y_train, cv=10, verbose=100, scoring = scoring)
print(lr_results)
# Out:
# [CV]  ................................................................
# [CV]  , accuracy=0.7089237839908081, precision=0.6511236302128653, recall=0.5846724494284559, total=  31.9s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   34.1s remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.7043800280934747, precision=0.646973897811799, recall=0.5844659983086689, total=  37.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.2min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.7059123994381306, precision=0.6535921010081506, recall=0.5909376630234028, total=  43.4s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  2.0min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.703206848089945, precision=0.6459755289322376, recall=0.592984576143964, total=  32.5s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  2.5min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.7040633784819831, precision=0.6551691312091324, recall=0.5905143985140197, total=  39.3s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  3.2min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.707641196013289, precision=0.654543436119039, recall=0.597239280076534, total=  30.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  3.7min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.699297124600639, precision=0.647661593224015, recall=0.5763898578786619, total=  29.2s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  4.3min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.6961523712130896, precision=0.6510018921626206, recall=0.5857124945891663, total=  29.9s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  4.8min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.7046791102019944, precision=0.6491305347426567, recall=0.5848688011796781, total=  30.3s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  5.3min remaining:    0.0s
# [CV]  ................................................................
# [CV]  , accuracy=0.7057018665302992, precision=0.6571953920823668, recall=0.5884889455550896, total=  27.3s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  5.8min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  5.8min finished
# {'fit_time': array([31.83, 36.95, 43.32, 32.47, 39.26, 30.  , 29.15, 29.82, 30.26,
#        27.28]), 'score_time': array([0.16, 0.14, 0.15, 0.16, 0.18, 0.14, 0.18, 0.17, 0.14, 0.13]), 'test_accuracy': array([0.71, 0.7 , 0.71, 0.7 , 0.7 , 0.71, 0.7 , 0.7 , 0.7 , 0.71]), 'train_accuracy': array([0.72, 0.72, 0.72, 0.72, 0.72, 0.72, 0.72, 0.72, 0.72, 0.72]), 'test_precision': array([0.65, 0.65, 0.65, 0.65, 0.66, 0.65, 0.65, 0.65, 0.65, 0.66]), 'train_precision': array([0.68, 0.68, 0.68, 0.68, 0.68, 0.67, 0.68, 0.68, 0.68, 0.68]), 'test_recall': array([0.58, 0.58, 0.59, 0.59, 0.59, 0.6 , 0.58, 0.59, 0.58, 0.59]), 'train_recall': array([0.61, 0.61, 0.61, 0.61, 0.61, 0.61, 0.61, 0.61, 0.61, 0.61])}

# %%
print(np.mean(lr_results['test_accuracy']))
print(np.std(lr_results['test_accuracy']))
# Out:
# 0.7039958106653652
# 0.0035916073893139163

# %%
label = ['articulated_truck'] + ['background'] + ['bicycle'] + \
    ['bus'] + ['car'] + ['motorcycle'] + ['non_motorized_vehicle']\
    + ['pedestrian'] + ['pickup_truck'] + ['single_unit_truck'] + \
    ['work_van']

# Compute confusion matrix
svc_cnf_matrix = confusion_matrix(y_test, svc_pred)
np.set_printoptions(precision=2)

# Plot normalized confusion matrix
plot_confusion_matrix(svc_cnf_matrix, classes=label, normalize=True,
                      title='LinearSVC Normalized Confusion Matrix')

plt.show()
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## Logistic Regression

# %%
# Compute confusion matrix
lr_cnf_matrix = confusion_matrix(y_test, lr_pred)
np.set_printoptions(precision=2)
plot_confusion_matrix(lr_cnf_matrix, classes=label, normalize=True,
                      title='Logistic Regression Normalized Confusion Matrix')

plt.show()
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## K Nearest Neighbors

# %%
# Compute confusion matrix
knn_cnf_matrix = confusion_matrix(y_test, knn_pred)
np.set_printoptions(precision=2)
plot_confusion_matrix(knn_cnf_matrix, classes = list(set(label)), normalize=True,
                      title='K Nearest Neighbors Normalized Confusion Matrix')

plt.show()
# Out:
# Normalized confusion matrix
